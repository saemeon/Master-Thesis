# %% [markdown]
# # Tutorial Sub-aggregated Temporal network

# %%
#load relevant Classes and functions
from Code import *

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
C = AronowSamii()
print(C.theta0)
# Out:
# /Users/simonniederberger/Dropbox/ETH/Master Thesis/Simulations/Code.py:877: RuntimeWarning: invalid value encountered in double_scalars
#   return y11 /_11 , y10 /_10, y01 /_01, y00 / _00
# (9.999999999999998, nan, 5.0, nan)

# %%
C.run_AS(50)

# %% [markdown]
# # Chin Multivariat

# %%
C = Chin_MV(intercept = False, direct = False)

# %%
pprint.pprint(C.run(10), width=1)
pprint.pprint(C.run_UV(10), width=1)
# Out:
# ana [4.44765529]
# ana LS [4.44765529]
# {'Analytical Estimator with 1 obs per Hi': array([4.45]),
#  'Analytical Estimator with 1 obs per Oij': array([4.43]),
#  'Analytical Estimator with 1 obs total': array([4.45]),
#  'Naiv estimator:': array([6.05]),
#  'True': array([4])}
# {'Analytical Estimator with 1 obs per Hi': 4.45,
#  'Analytical Estimator with 1 obs per Oij': 4.43,
#  'Analytical Estimator with 1 obs total': array([[4.45]]),
#  'Iterative Confidence Interval': array([4.15, 4.73]),
#  'Iterative Estimator': 4.44,
#  'Naiv estimator:': 6.05}

# %% [markdown]
# # Chin Univariat

# %%
C_UV = Chin_UV()
C_UV.run_UV(10)
# Out:
# {'Naiv estimator:': 6.67,
#  'Analytical Estimator with 1 obs per Oij': 6.95,
#  'Analytical Estimator with 1 obs per Hi': 6.97,
#  'Analytical Estimator with 1 obs total': array([[6.97]]),
#  'Iterative Estimator': 6.96,
#  'Iterative Confidence Interval': array([6.56, 7.36])}

# %%
C.run_UV(10)
tikzplotlib.save("fig/Chin_UV.tex")
